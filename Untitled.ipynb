# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from keras import models
from keras.models import Sequential
from keras import layers
from keras.layers import Dense, Dropout, Activation
from keras import optimizers
from keras import regularizers

# %%
x_test = pd.read_excel('C:\\Users\\Daniel\\Documents\\Flatiron\\Capstone\\sports_predictions\\10_29_21_stats.xlsx')

# %%
x_test
# Out:
#    Home Points For  Home Points Against  Home eFG%  Home FTr  Home ORB%  \
# 0            103.8                 99.0      0.471     0.226       36.5
# 1            102.0                108.6      0.502     0.205       19.2
# 2            110.3                 95.0      0.497     0.243       24.5
# 3            100.8                108.2      0.490     0.178       26.9
# 4            102.3                103.8      0.555     0.157       18.0
# 5            114.3                110.3      0.548     0.247       21.6
# 6            116.0                119.6      0.547     0.229       19.4
#
#    Home DRB%  Home AST%  Home STL%  Home BLK%  Home TOV%  ...  Away DRB%  \
# 0       75.3       53.1       11.8        3.8       15.3  ...       72.0
# 1       72.3       56.6        6.4        6.8       13.4  ...       78.4
# 2       85.4       57.6        7.0        2.0       12.6  ...       80.3
# 3       75.1       58.6        6.4        5.4       15.8  ...       73.8
# 4       79.0       55.2        9.5        2.3       15.4  ...       79.3
# 5       79.5       51.5        8.8        5.0       13.4  ...       74.1
# 6       74.8       56.6        8.0        6.2       12.9  ...       74.8
#
#    Away AST%  Away STL%  Away BLK%  Away TOV%  Away ORTG  Away DRtg  Away GP  \
# 0       58.9        6.2        4.2       17.1      101.6      115.9        5
# 1       55.7        5.8        5.8       11.0      108.3      112.0        5
# 2       59.7       10.0        4.2       11.5      115.6      110.6        5
# 3       58.6        7.0        4.8       10.8      108.6      112.3        4
# 4       54.2        6.5        5.8       12.9      103.8      104.5        4
# 5       64.4       12.5        3.5       17.9      103.9      101.7        5
# 6       63.1        7.6        4.4       13.2      105.9      104.1        5
#
#    Away Win Rate  Vegas Prediction
# 0           0.33               8.0
# 1           0.00               8.5
# 2           1.00               7.0
# 3           1.00              -1.5
# 4           1.00               2.0
# 5           0.00               3.0
# 6           0.67               7.5
#
# [7 rows x 29 columns]

# %%
df = pd.read_csv('avg_by_game')
odds = pd.read_csv('nba_game_odds')

# %%
data = df.set_index(df['Unnamed: 0'], drop=True)
data.index.rename('GameID', inplace=True)
data.drop(columns='Unnamed: 0', inplace=True)

odds.set_index(odds['GameID'], drop=True, inplace=True)

# %%
data.sort_index(inplace=True)
odds.sort_index(inplace=True)
data['Home Wins By (Vegas)'] = odds['Home Win By (Vegas)']

# %%
for i in range(len(data)):
    data['Home Wins By (Vegas)'][i] = odds['Home Win By (Vegas)'][i]
# Out:
# <ipython-input-7-3759b8bb49ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Home Wins By (Vegas)'][i] = odds['Home Win By (Vegas)'][i]

# %%
results = pd.DataFrame(columns=['linreg', 'forest', 'gb', 'NN', 'Vegas Prediction'],
                      index = range(len(x_test)))

# %%
x = data.drop(columns='Home Win By')
y = data['Home Win By']

# %%
linreg = LinearRegression()
forest = RandomForestRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=3, n_estimators=200)
gb = GradientBoostingRegressor(learning_rate=0.2, max_depth=1, min_samples_leaf=5, min_samples_split=3, n_estimators=200, random_state=42)
ml_models = [linreg, forest, gb]

# %%
#function to train/test models and prints RMSE
def run_model(x, y, x_test, model):

    model.fit(x, y)
    y_test_pred = model.predict(x_test)
    
    return y_test_pred

# %%
nn = models.Sequential()
nn.add(Dense(500, input_dim=29, activation= 'relu'))
nn.add(Dense(250, activation= 'relu'))
nn.add(Dense(125, activation= 'relu'))

nn.add(Dense(1, activation='linear'))

nn.compile(loss='mse', optimizer='adam', metrics=['mean_squared_error'])

# %%
test_preds = nn.predict(x_test)
results['NN'] = test_preds

# %%
for model in ml_models:
    preds = run_model(x, y, x_test, model)
    results['{}'.format(model)] = preds

# %%
results['Vegas Prediction'] = x_test['Vegas Prediction']

# %%
results
# Out:
#   linreg forest   gb        NN  Vegas Prediction  LinearRegression()  \
# 0    NaN    NaN  NaN  7.785965               8.0           12.049093
# 1    NaN    NaN  NaN  8.702753               8.5           -4.642519
# 2    NaN    NaN  NaN  8.078774               7.0            7.384968
# 3    NaN    NaN  NaN  7.732629              -1.5           -4.590941
# 4    NaN    NaN  NaN  8.108269               2.0           -2.328938
# 5    NaN    NaN  NaN  8.225163               3.0            0.449570
# 6    NaN    NaN  NaN  9.092093               7.5           -4.846784
#
#    RandomForestRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=3,\n                      n_estimators=200)  \
# 0                                           1.634188
# 1                                           6.250815
# 2                                           5.412549
# 3                                          -9.125723
# 4                                          -5.385863
# 5                                           7.751486
# 6                                          -4.893339
#
#    GradientBoostingRegressor(learning_rate=0.2, max_depth=1, min_samples_leaf=5,\n                          min_samples_split=3, n_estimators=200,\n                          random_state=42)
# 0                                           4.381805
# 1                                          -0.079328
# 2                                           4.242323
# 3                                         -10.230152
# 4                                          -2.035545
# 5                                           5.028581
# 6                                          -4.917829
