# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras import models
from keras.models import Sequential
from keras import layers
from keras.layers import Dense, Dropout, Activation
from keras import optimizers
from keras import regularizers
from sklearn.metrics import mean_squared_error
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import pickle
from keras.models import load_model

# %%
df = pd.read_csv('avg_by_game_2')

# %%
df.set_index('GameID', inplace=True)

# %%
stats = pd.read_excel('C:\\Users\\Daniel\\Documents\\Flatiron\\Capstone\\sports_predictions\\stats.xlsx')

# %%
y = df['Home Win By']
x = df.drop(columns='Home Win By')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
nn_model = models.Sequential()
nn_model.add(Dense(500, input_dim=30, activation= 'relu'))
nn_model.add(Dense(250, activation= 'relu'))
nn_model.add(Dense(125, activation= 'relu'))

nn_model.add(Dense(1, activation='linear'))

# %%
nn_model.compile(loss='mse', optimizer='adam', metrics=['mean_squared_error'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = ModelCheckpoint('best_model_2.h5', monitor='val_mean_squared_error', mode='min', verbose=1, save_best_only=True)

# %%
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 500)               15500
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               125250
# _________________________________________________________________
# dense_6 (Dense)              (None, 125)               31375
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 126
# =================================================================
# Total params: 172,251
# Trainable params: 172,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = nn_model.fit(x_train, y_train, epochs=200, verbose=2, batch_size=300, validation_data=(x_test, y_test), callbacks=[es, mc])
# Out:
# Epoch 1/200
# 27/27 - 2s - loss: 2109.2031 - mean_squared_error: 2109.2031 - val_loss: 457.0002 - val_mean_squared_error: 457.0002
#
# Epoch 00001: val_mean_squared_error improved from inf to 457.00015, saving model to best_model_2.h5
# Epoch 2/200
# 27/27 - 0s - loss: 245.0455 - mean_squared_error: 245.0455 - val_loss: 204.5067 - val_mean_squared_error: 204.5067
#
# Epoch 00002: val_mean_squared_error improved from 457.00015 to 204.50673, saving model to best_model_2.h5
# Epoch 3/200
# 27/27 - 0s - loss: 188.5817 - mean_squared_error: 188.5817 - val_loss: 194.7289 - val_mean_squared_error: 194.7289
#
# Epoch 00003: val_mean_squared_error improved from 204.50673 to 194.72885, saving model to best_model_2.h5
# Epoch 4/200
# 27/27 - 0s - loss: 182.6353 - mean_squared_error: 182.6353 - val_loss: 183.3351 - val_mean_squared_error: 183.3351
#
# Epoch 00004: val_mean_squared_error improved from 194.72885 to 183.33514, saving model to best_model_2.h5
# Epoch 5/200
# 27/27 - 0s - loss: 179.6901 - mean_squared_error: 179.6901 - val_loss: 184.8531 - val_mean_squared_error: 184.8531
#
# Epoch 00005: val_mean_squared_error did not improve from 183.33514
# Epoch 6/200
# 27/27 - 0s - loss: 174.5307 - mean_squared_error: 174.5307 - val_loss: 176.2015 - val_mean_squared_error: 176.2015
#
# Epoch 00006: val_mean_squared_error improved from 183.33514 to 176.20151, saving model to best_model_2.h5
# Epoch 7/200
# 27/27 - 0s - loss: 172.0940 - mean_squared_error: 172.0940 - val_loss: 177.8358 - val_mean_squared_error: 177.8358
#
# Epoch 00007: val_mean_squared_error did not improve from 176.20151
# Epoch 8/200
# 27/27 - 0s - loss: 167.6023 - mean_squared_error: 167.6023 - val_loss: 169.0738 - val_mean_squared_error: 169.0738
#
# Epoch 00008: val_mean_squared_error improved from 176.20151 to 169.07384, saving model to best_model_2.h5
# Epoch 9/200
# 27/27 - 0s - loss: 163.3014 - mean_squared_error: 163.3014 - val_loss: 165.8185 - val_mean_squared_error: 165.8185
#
# Epoch 00009: val_mean_squared_error improved from 169.07384 to 165.81853, saving model to best_model_2.h5
# Epoch 10/200
# 27/27 - 0s - loss: 159.6615 - mean_squared_error: 159.6615 - val_loss: 161.3226 - val_mean_squared_error: 161.3226
#
# Epoch 00010: val_mean_squared_error improved from 165.81853 to 161.32256, saving model to best_model_2.h5
# Epoch 11/200
# 27/27 - 0s - loss: 159.0798 - mean_squared_error: 159.0798 - val_loss: 182.5864 - val_mean_squared_error: 182.5864
#
# Epoch 00011: val_mean_squared_error did not improve from 161.32256
# Epoch 12/200
# 27/27 - 0s - loss: 159.7352 - mean_squared_error: 159.7352 - val_loss: 171.0105 - val_mean_squared_error: 171.0105
#
# Epoch 00012: val_mean_squared_error did not improve from 161.32256
# Epoch 13/200
# 27/27 - 0s - loss: 157.2692 - mean_squared_error: 157.2692 - val_loss: 154.6445 - val_mean_squared_error: 154.6445
#
# Epoch 00013: val_mean_squared_error improved from 161.32256 to 154.64449, saving model to best_model_2.h5
# Epoch 14/200
# 27/27 - 0s - loss: 157.8719 - mean_squared_error: 157.8719 - val_loss: 159.0544 - val_mean_squared_error: 159.0544
#
# Epoch 00014: val_mean_squared_error did not improve from 154.64449
# Epoch 15/200
# 27/27 - 0s - loss: 149.5429 - mean_squared_error: 149.5429 - val_loss: 153.0391 - val_mean_squared_error: 153.0391
#
# Epoch 00015: val_mean_squared_error improved from 154.64449 to 153.03906, saving model to best_model_2.h5
# Epoch 16/200
# 27/27 - 0s - loss: 148.8246 - mean_squared_error: 148.8246 - val_loss: 156.4287 - val_mean_squared_error: 156.4287
#
# Epoch 00016: val_mean_squared_error did not improve from 153.03906
# Epoch 17/200
# 27/27 - 0s - loss: 148.2577 - mean_squared_error: 148.2577 - val_loss: 153.2419 - val_mean_squared_error: 153.2419
#
# Epoch 00017: val_mean_squared_error did not improve from 153.03906
# Epoch 18/200
# 27/27 - 0s - loss: 148.2707 - mean_squared_error: 148.2707 - val_loss: 152.5015 - val_mean_squared_error: 152.5015
#
# Epoch 00018: val_mean_squared_error improved from 153.03906 to 152.50153, saving model to best_model_2.h5
# Epoch 19/200
# 27/27 - 0s - loss: 146.1926 - mean_squared_error: 146.1926 - val_loss: 150.4759 - val_mean_squared_error: 150.4759
#
# Epoch 00019: val_mean_squared_error improved from 152.50153 to 150.47588, saving model to best_model_2.h5
# Epoch 20/200
# 27/27 - 0s - loss: 146.2495 - mean_squared_error: 146.2495 - val_loss: 154.9307 - val_mean_squared_error: 154.9307
#
# Epoch 00020: val_mean_squared_error did not improve from 150.47588
# Epoch 21/200
# 27/27 - 0s - loss: 151.2690 - mean_squared_error: 151.2690 - val_loss: 160.0029 - val_mean_squared_error: 160.0029
#
# Epoch 00021: val_mean_squared_error did not improve from 150.47588
# Epoch 22/200
# 27/27 - 0s - loss: 146.8618 - mean_squared_error: 146.8618 - val_loss: 152.6370 - val_mean_squared_error: 152.6370
#
# Epoch 00022: val_mean_squared_error did not improve from 150.47588
# Epoch 23/200
# 27/27 - 0s - loss: 149.0337 - mean_squared_error: 149.0337 - val_loss: 149.4213 - val_mean_squared_error: 149.4213
#
# Epoch 00023: val_mean_squared_error improved from 150.47588 to 149.42131, saving model to best_model_2.h5
# Epoch 24/200
# 27/27 - 0s - loss: 147.2094 - mean_squared_error: 147.2094 - val_loss: 149.4896 - val_mean_squared_error: 149.4896
#
# Epoch 00024: val_mean_squared_error did not improve from 149.42131
# Epoch 25/200
# 27/27 - 0s - loss: 148.1870 - mean_squared_error: 148.1870 - val_loss: 154.6637 - val_mean_squared_error: 154.6637
#
# Epoch 00025: val_mean_squared_error did not improve from 149.42131
# Epoch 26/200
# 27/27 - 0s - loss: 147.1201 - mean_squared_error: 147.1201 - val_loss: 153.2814 - val_mean_squared_error: 153.2814
#
# Epoch 00026: val_mean_squared_error did not improve from 149.42131
# Epoch 27/200
# 27/27 - 0s - loss: 147.9515 - mean_squared_error: 147.9515 - val_loss: 151.5818 - val_mean_squared_error: 151.5818
#
# Epoch 00027: val_mean_squared_error did not improve from 149.42131
# Epoch 28/200
# 27/27 - 0s - loss: 147.4051 - mean_squared_error: 147.4051 - val_loss: 148.6987 - val_mean_squared_error: 148.6988
#
# Epoch 00028: val_mean_squared_error improved from 149.42131 to 148.69876, saving model to best_model_2.h5
# Epoch 29/200
# 27/27 - 0s - loss: 151.0559 - mean_squared_error: 151.0559 - val_loss: 148.2643 - val_mean_squared_error: 148.2643
#
# Epoch 00029: val_mean_squared_error improved from 148.69876 to 148.26428, saving model to best_model_2.h5
# Epoch 30/200
# 27/27 - 0s - loss: 150.2837 - mean_squared_error: 150.2837 - val_loss: 148.4545 - val_mean_squared_error: 148.4545
#
# Epoch 00030: val_mean_squared_error did not improve from 148.26428
# Epoch 31/200
# 27/27 - 0s - loss: 145.5291 - mean_squared_error: 145.5291 - val_loss: 147.9316 - val_mean_squared_error: 147.9316
#
# Epoch 00031: val_mean_squared_error improved from 148.26428 to 147.93164, saving model to best_model_2.h5
# Epoch 32/200
# 27/27 - 0s - loss: 154.0750 - mean_squared_error: 154.0750 - val_loss: 159.3489 - val_mean_squared_error: 159.3489
#
# Epoch 00032: val_mean_squared_error did not improve from 147.93164
# Epoch 33/200
# 27/27 - 0s - loss: 144.4016 - mean_squared_error: 144.4016 - val_loss: 148.8326 - val_mean_squared_error: 148.8326
#
# Epoch 00033: val_mean_squared_error did not improve from 147.93164
# Epoch 34/200
# 27/27 - 0s - loss: 145.6950 - mean_squared_error: 145.6950 - val_loss: 147.3028 - val_mean_squared_error: 147.3028
#
# Epoch 00034: val_mean_squared_error improved from 147.93164 to 147.30284, saving model to best_model_2.h5
# Epoch 35/200
# 27/27 - 0s - loss: 147.2467 - mean_squared_error: 147.2467 - val_loss: 148.9430 - val_mean_squared_error: 148.9430
#
# Epoch 00035: val_mean_squared_error did not improve from 147.30284
# Epoch 36/200
# 27/27 - 0s - loss: 144.4009 - mean_squared_error: 144.4009 - val_loss: 153.1574 - val_mean_squared_error: 153.1574
#
# Epoch 00036: val_mean_squared_error did not improve from 147.30284
# Epoch 37/200
# 27/27 - 0s - loss: 149.8039 - mean_squared_error: 149.8039 - val_loss: 167.5587 - val_mean_squared_error: 167.5587
#
# Epoch 00037: val_mean_squared_error did not improve from 147.30284
# Epoch 38/200
# 27/27 - 0s - loss: 147.5658 - mean_squared_error: 147.5658 - val_loss: 147.0685 - val_mean_squared_error: 147.0685
#
# Epoch 00038: val_mean_squared_error improved from 147.30284 to 147.06845, saving model to best_model_2.h5
# Epoch 39/200
# 27/27 - 0s - loss: 146.4476 - mean_squared_error: 146.4476 - val_loss: 172.2608 - val_mean_squared_error: 172.2608
# Epoch 00039: val_mean_squared_error did not improve from 147.06845
# Epoch 40/200
# 27/27 - 0s - loss: 146.9576 - mean_squared_error: 146.9576 - val_loss: 150.2641 - val_mean_squared_error: 150.2641
#
# Epoch 00040: val_mean_squared_error did not improve from 147.06845
# Epoch 41/200
# 27/27 - 0s - loss: 148.5354 - mean_squared_error: 148.5354 - val_loss: 298.0085 - val_mean_squared_error: 298.0085
#
# Epoch 00041: val_mean_squared_error did not improve from 147.06845
# Epoch 42/200
# 27/27 - 0s - loss: 161.1009 - mean_squared_error: 161.1009 - val_loss: 155.7693 - val_mean_squared_error: 155.7693
#
# Epoch 00042: val_mean_squared_error did not improve from 147.06845
# Epoch 43/200
# 27/27 - 0s - loss: 148.4212 - mean_squared_error: 148.4212 - val_loss: 153.5969 - val_mean_squared_error: 153.5969
#
# Epoch 00043: val_mean_squared_error did not improve from 147.06845
# Epoch 44/200
# 27/27 - 0s - loss: 143.7755 - mean_squared_error: 143.7755 - val_loss: 147.0081 - val_mean_squared_error: 147.0081
#
# Epoch 00044: val_mean_squared_error improved from 147.06845 to 147.00806, saving model to best_model_2.h5
# Epoch 45/200
# 27/27 - 0s - loss: 154.2680 - mean_squared_error: 154.2680 - val_loss: 153.2313 - val_mean_squared_error: 153.2313
#
# Epoch 00045: val_mean_squared_error did not improve from 147.00806
# Epoch 46/200
# 27/27 - 0s - loss: 143.7139 - mean_squared_error: 143.7139 - val_loss: 145.6752 - val_mean_squared_error: 145.6752
#
# Epoch 00046: val_mean_squared_error improved from 147.00806 to 145.67522, saving model to best_model_2.h5
# Epoch 47/200
# 27/27 - 0s - loss: 142.5151 - mean_squared_error: 142.5151 - val_loss: 146.7073 - val_mean_squared_error: 146.7073
#
# Epoch 00047: val_mean_squared_error did not improve from 145.67522
# Epoch 48/200
# 27/27 - 0s - loss: 141.9354 - mean_squared_error: 141.9354 - val_loss: 149.7038 - val_mean_squared_error: 149.7038
#
# Epoch 00048: val_mean_squared_error did not improve from 145.67522
# Epoch 49/200
# 27/27 - 0s - loss: 145.4105 - mean_squared_error: 145.4105 - val_loss: 150.3580 - val_mean_squared_error: 150.3580
#
# Epoch 00049: val_mean_squared_error did not improve from 145.67522
# Epoch 50/200
# 27/27 - 0s - loss: 142.7920 - mean_squared_error: 142.7920 - val_loss: 149.5934 - val_mean_squared_error: 149.5934
#
# Epoch 00050: val_mean_squared_error did not improve from 145.67522
# Epoch 51/200
# 27/27 - 0s - loss: 148.7835 - mean_squared_error: 148.7835 - val_loss: 157.5822 - val_mean_squared_error: 157.5822
#
# Epoch 00051: val_mean_squared_error did not improve from 145.67522
# Epoch 52/200
# 27/27 - 0s - loss: 144.1024 - mean_squared_error: 144.1024 - val_loss: 147.6898 - val_mean_squared_error: 147.6898
#
# Epoch 00052: val_mean_squared_error did not improve from 145.67522
# Epoch 53/200
# 27/27 - 0s - loss: 141.2907 - mean_squared_error: 141.2907 - val_loss: 145.0525 - val_mean_squared_error: 145.0525
#
# Epoch 00053: val_mean_squared_error improved from 145.67522 to 145.05249, saving model to best_model_2.h5
# Epoch 54/200
# 27/27 - 0s - loss: 141.8602 - mean_squared_error: 141.8601 - val_loss: 143.4665 - val_mean_squared_error: 143.4665
#
# Epoch 00054: val_mean_squared_error improved from 145.05249 to 143.46654, saving model to best_model_2.h5
# Epoch 55/200
# 27/27 - 0s - loss: 143.2386 - mean_squared_error: 143.2386 - val_loss: 143.6697 - val_mean_squared_error: 143.6697
#
# Epoch 00055: val_mean_squared_error did not improve from 143.46654
# Epoch 56/200
# 27/27 - 0s - loss: 142.1797 - mean_squared_error: 142.1797 - val_loss: 153.0344 - val_mean_squared_error: 153.0343
#
# Epoch 00056: val_mean_squared_error did not improve from 143.46654
# Epoch 57/200
# 27/27 - 0s - loss: 143.2995 - mean_squared_error: 143.2995 - val_loss: 143.1834 - val_mean_squared_error: 143.1834
#
# Epoch 00057: val_mean_squared_error improved from 143.46654 to 143.18341, saving model to best_model_2.h5
# Epoch 58/200
# 27/27 - 0s - loss: 148.0968 - mean_squared_error: 148.0968 - val_loss: 152.5007 - val_mean_squared_error: 152.5007
#
# Epoch 00058: val_mean_squared_error did not improve from 143.18341
# Epoch 59/200
# 27/27 - 0s - loss: 140.6606 - mean_squared_error: 140.6606 - val_loss: 142.8835 - val_mean_squared_error: 142.8835
#
# Epoch 00059: val_mean_squared_error improved from 143.18341 to 142.88348, saving model to best_model_2.h5
# Epoch 60/200
# 27/27 - 0s - loss: 141.2003 - mean_squared_error: 141.2003 - val_loss: 158.9752 - val_mean_squared_error: 158.9752
#
# Epoch 00060: val_mean_squared_error did not improve from 142.88348
# Epoch 61/200
# 27/27 - 0s - loss: 140.3817 - mean_squared_error: 140.3817 - val_loss: 143.2499 - val_mean_squared_error: 143.2499
#
# Epoch 00061: val_mean_squared_error did not improve from 142.88348
# Epoch 62/200
# 27/27 - 0s - loss: 137.9800 - mean_squared_error: 137.9800 - val_loss: 147.6746 - val_mean_squared_error: 147.6746
#
# Epoch 00062: val_mean_squared_error did not improve from 142.88348
# Epoch 63/200
# 27/27 - 0s - loss: 148.2692 - mean_squared_error: 148.2692 - val_loss: 142.1222 - val_mean_squared_error: 142.1222
#
# Epoch 00063: val_mean_squared_error improved from 142.88348 to 142.12219, saving model to best_model_2.h5
# Epoch 64/200
# 27/27 - 0s - loss: 138.7265 - mean_squared_error: 138.7265 - val_loss: 167.3591 - val_mean_squared_error: 167.3591
#
# Epoch 00064: val_mean_squared_error did not improve from 142.12219
# Epoch 65/200
# 27/27 - 0s - loss: 144.3906 - mean_squared_error: 144.3906 - val_loss: 148.7705 - val_mean_squared_error: 148.7705
#
# Epoch 00065: val_mean_squared_error did not improve from 142.12219
# Epoch 66/200
# 27/27 - 0s - loss: 138.6070 - mean_squared_error: 138.6070 - val_loss: 150.5399 - val_mean_squared_error: 150.5399
#
# Epoch 00066: val_mean_squared_error did not improve from 142.12219
# Epoch 67/200
# 27/27 - 0s - loss: 139.6298 - mean_squared_error: 139.6298 - val_loss: 141.4453 - val_mean_squared_error: 141.4453
#
# Epoch 00067: val_mean_squared_error improved from 142.12219 to 141.44533, saving model to best_model_2.h5
# Epoch 68/200
# 27/27 - 0s - loss: 136.4822 - mean_squared_error: 136.4822 - val_loss: 146.0389 - val_mean_squared_error: 146.0389
#
# Epoch 00068: val_mean_squared_error did not improve from 141.44533
# Epoch 69/200
# 27/27 - 0s - loss: 138.2629 - mean_squared_error: 138.2629 - val_loss: 139.4321 - val_mean_squared_error: 139.4321
#
# Epoch 00069: val_mean_squared_error improved from 141.44533 to 139.43214, saving model to best_model_2.h5
# Epoch 70/200
# 27/27 - 0s - loss: 141.5142 - mean_squared_error: 141.5142 - val_loss: 139.7988 - val_mean_squared_error: 139.7988
#
# Epoch 00070: val_mean_squared_error did not improve from 139.43214
# Epoch 71/200
# 27/27 - 0s - loss: 146.8498 - mean_squared_error: 146.8498 - val_loss: 142.0140 - val_mean_squared_error: 142.0140
#
# Epoch 00071: val_mean_squared_error did not improve from 139.43214
# Epoch 72/200
# 27/27 - 0s - loss: 139.8758 - mean_squared_error: 139.8758 - val_loss: 139.8528 - val_mean_squared_error: 139.8528
#
# Epoch 00072: val_mean_squared_error did not improve from 139.43214
# Epoch 73/200
# 27/27 - 0s - loss: 140.2136 - mean_squared_error: 140.2136 - val_loss: 138.7703 - val_mean_squared_error: 138.7703
#
# Epoch 00073: val_mean_squared_error improved from 139.43214 to 138.77034, saving model to best_model_2.h5
# Epoch 74/200
# 27/27 - 0s - loss: 137.4798 - mean_squared_error: 137.4798 - val_loss: 138.5598 - val_mean_squared_error: 138.5598
#
# Epoch 00074: val_mean_squared_error improved from 138.77034 to 138.55978, saving model to best_model_2.h5
# Epoch 75/200
# 27/27 - 0s - loss: 137.2399 - mean_squared_error: 137.2399 - val_loss: 138.3254 - val_mean_squared_error: 138.3254
#
# Epoch 00075: val_mean_squared_error improved from 138.55978 to 138.32542, saving model to best_model_2.h5
# Epoch 76/200
# 27/27 - 0s - loss: 144.8756 - mean_squared_error: 144.8756 - val_loss: 194.1712 - val_mean_squared_error: 194.1712
#
# Epoch 00076: val_mean_squared_error did not improve from 138.32542
# Epoch 77/200
# 27/27 - 0s - loss: 148.7477 - mean_squared_error: 148.7477 - val_loss: 144.6506 - val_mean_squared_error: 144.6506
#
# Epoch 00077: val_mean_squared_error did not improve from 138.32542
# Epoch 78/200
# 27/27 - 0s - loss: 138.1767 - mean_squared_error: 138.1767 - val_loss: 138.4121 - val_mean_squared_error: 138.4121
#
# Epoch 00078: val_mean_squared_error did not improve from 138.32542
# Epoch 79/200
# 27/27 - 0s - loss: 143.4051 - mean_squared_error: 143.4050 - val_loss: 140.4355 - val_mean_squared_error: 140.4355
#
# Epoch 00079: val_mean_squared_error did not improve from 138.32542
# Epoch 80/200
# 27/27 - 0s - loss: 142.5294 - mean_squared_error: 142.5294 - val_loss: 138.6219 - val_mean_squared_error: 138.6219
#
# Epoch 00080: val_mean_squared_error did not improve from 138.32542
# Epoch 81/200
# 27/27 - 0s - loss: 135.4582 - mean_squared_error: 135.4582 - val_loss: 141.9327 - val_mean_squared_error: 141.9327
#
# Epoch 00081: val_mean_squared_error did not improve from 138.32542
# Epoch 82/200
# 27/27 - 0s - loss: 135.5672 - mean_squared_error: 135.5672 - val_loss: 137.6290 - val_mean_squared_error: 137.6290
#
# Epoch 00082: val_mean_squared_error improved from 138.32542 to 137.62898, saving model to best_model_2.h5
# Epoch 83/200
# 27/27 - 0s - loss: 135.2066 - mean_squared_error: 135.2066 - val_loss: 138.1974 - val_mean_squared_error: 138.1973
#
# Epoch 00083: val_mean_squared_error did not improve from 137.62898
# Epoch 84/200
# 27/27 - 0s - loss: 141.1945 - mean_squared_error: 141.1945 - val_loss: 255.1674 - val_mean_squared_error: 255.1674
#
# Epoch 00084: val_mean_squared_error did not improve from 137.62898
# Epoch 85/200
# 27/27 - 0s - loss: 146.8236 - mean_squared_error: 146.8236 - val_loss: 138.3800 - val_mean_squared_error: 138.3800
#
# Epoch 00085: val_mean_squared_error did not improve from 137.62898
# Epoch 86/200
# 27/27 - 0s - loss: 135.8557 - mean_squared_error: 135.8557 - val_loss: 137.1237 - val_mean_squared_error: 137.1237
#
# Epoch 00086: val_mean_squared_error improved from 137.62898 to 137.12375, saving model to best_model_2.h5
# Epoch 87/200
# 27/27 - 0s - loss: 136.9178 - mean_squared_error: 136.9178 - val_loss: 136.7102 - val_mean_squared_error: 136.7102
#
# Epoch 00087: val_mean_squared_error improved from 137.12375 to 136.71016, saving model to best_model_2.h5
# Epoch 88/200
# 27/27 - 0s - loss: 133.3667 - mean_squared_error: 133.3667 - val_loss: 136.5548 - val_mean_squared_error: 136.5548
#
# Epoch 00088: val_mean_squared_error improved from 136.71016 to 136.55479, saving model to best_model_2.h5
# Epoch 89/200
# 27/27 - 0s - loss: 138.4426 - mean_squared_error: 138.4426 - val_loss: 151.4781 - val_mean_squared_error: 151.4781
#
# Epoch 00089: val_mean_squared_error did not improve from 136.55479
# Epoch 90/200
# 27/27 - 0s - loss: 134.9090 - mean_squared_error: 134.9090 - val_loss: 149.8293 - val_mean_squared_error: 149.8293
#
# Epoch 00090: val_mean_squared_error did not improve from 136.55479
# Epoch 91/200
# 27/27 - 0s - loss: 137.7122 - mean_squared_error: 137.7122 - val_loss: 140.2142 - val_mean_squared_error: 140.2142
#
# Epoch 00091: val_mean_squared_error did not improve from 136.55479
# Epoch 92/200
# 27/27 - 0s - loss: 136.7343 - mean_squared_error: 136.7343 - val_loss: 154.9052 - val_mean_squared_error: 154.9052
#
# Epoch 00092: val_mean_squared_error did not improve from 136.55479
# Epoch 93/200
# 27/27 - 0s - loss: 137.0354 - mean_squared_error: 137.0354 - val_loss: 140.6922 - val_mean_squared_error: 140.6922
#
# Epoch 00093: val_mean_squared_error did not improve from 136.55479
# Epoch 94/200
# 27/27 - 0s - loss: 137.4630 - mean_squared_error: 137.4630 - val_loss: 136.1705 - val_mean_squared_error: 136.1705
#
# Epoch 00094: val_mean_squared_error improved from 136.55479 to 136.17055, saving model to best_model_2.h5
# Epoch 95/200
# 27/27 - 0s - loss: 144.6553 - mean_squared_error: 144.6553 - val_loss: 140.0101 - val_mean_squared_error: 140.0101
#
# Epoch 00095: val_mean_squared_error did not improve from 136.17055
# Epoch 96/200
# 27/27 - 0s - loss: 136.9001 - mean_squared_error: 136.9001 - val_loss: 146.3522 - val_mean_squared_error: 146.3522
#
# Epoch 00096: val_mean_squared_error did not improve from 136.17055
# Epoch 97/200
# 27/27 - 0s - loss: 143.7128 - mean_squared_error: 143.7128 - val_loss: 141.7339 - val_mean_squared_error: 141.7339
#
# Epoch 00097: val_mean_squared_error did not improve from 136.17055
# Epoch 98/200
# 27/27 - 0s - loss: 140.7744 - mean_squared_error: 140.7744 - val_loss: 137.8186 - val_mean_squared_error: 137.8186
#
# Epoch 00098: val_mean_squared_error did not improve from 136.17055
# Epoch 99/200
# 27/27 - 0s - loss: 132.1568 - mean_squared_error: 132.1568 - val_loss: 136.1938 - val_mean_squared_error: 136.1938
#
# Epoch 00099: val_mean_squared_error did not improve from 136.17055
# Epoch 100/200
# 27/27 - 0s - loss: 135.5381 - mean_squared_error: 135.5381 - val_loss: 136.8358 - val_mean_squared_error: 136.8358
#
# Epoch 00100: val_mean_squared_error did not improve from 136.17055
# Epoch 101/200
# 27/27 - 0s - loss: 136.1438 - mean_squared_error: 136.1438 - val_loss: 136.0744 - val_mean_squared_error: 136.0744
#
# Epoch 00101: val_mean_squared_error improved from 136.17055 to 136.07439, saving model to best_model_2.h5
# Epoch 102/200
# 27/27 - 0s - loss: 136.6351 - mean_squared_error: 136.6351 - val_loss: 135.5597 - val_mean_squared_error: 135.5597
#
# Epoch 00102: val_mean_squared_error improved from 136.07439 to 135.55966, saving model to best_model_2.h5
# Epoch 103/200
# 27/27 - 0s - loss: 134.7360 - mean_squared_error: 134.7360 - val_loss: 149.3972 - val_mean_squared_error: 149.3972
#
# Epoch 00103: val_mean_squared_error did not improve from 135.55966
# Epoch 104/200
# 27/27 - 0s - loss: 142.5690 - mean_squared_error: 142.5690 - val_loss: 140.1328 - val_mean_squared_error: 140.1328
#
# Epoch 00104: val_mean_squared_error did not improve from 135.55966
# Epoch 105/200
# 27/27 - 0s - loss: 140.5179 - mean_squared_error: 140.5179 - val_loss: 169.2845 - val_mean_squared_error: 169.2845
#
# Epoch 00105: val_mean_squared_error did not improve from 135.55966
# Epoch 106/200
# 27/27 - 0s - loss: 144.3356 - mean_squared_error: 144.3356 - val_loss: 145.2990 - val_mean_squared_error: 145.2990
#
# Epoch 00106: val_mean_squared_error did not improve from 135.55966
# Epoch 107/200
# 27/27 - 0s - loss: 143.2653 - mean_squared_error: 143.2653 - val_loss: 136.1497 - val_mean_squared_error: 136.1497
#
# Epoch 00107: val_mean_squared_error did not improve from 135.55966
# Epoch 108/200
# 27/27 - 0s - loss: 133.9543 - mean_squared_error: 133.9543 - val_loss: 136.4976 - val_mean_squared_error: 136.4976
#
# Epoch 00108: val_mean_squared_error did not improve from 135.55966
# Epoch 109/200
# 27/27 - 0s - loss: 132.7063 - mean_squared_error: 132.7063 - val_loss: 136.7503 - val_mean_squared_error: 136.7503
#
# Epoch 00109: val_mean_squared_error did not improve from 135.55966
# Epoch 110/200
# 27/27 - 0s - loss: 133.4725 - mean_squared_error: 133.4725 - val_loss: 135.1546 - val_mean_squared_error: 135.1546
#
# Epoch 00110: val_mean_squared_error improved from 135.55966 to 135.15456, saving model to best_model_2.h5
# Epoch 111/200
# 27/27 - 0s - loss: 130.9659 - mean_squared_error: 130.9659 - val_loss: 135.5046 - val_mean_squared_error: 135.5046
#
# Epoch 00111: val_mean_squared_error did not improve from 135.15456
# Epoch 112/200
# 27/27 - 0s - loss: 140.3368 - mean_squared_error: 140.3368 - val_loss: 152.9231 - val_mean_squared_error: 152.9231
#
# Epoch 00112: val_mean_squared_error did not improve from 135.15456
# Epoch 113/200
# 27/27 - 0s - loss: 136.2437 - mean_squared_error: 136.2437 - val_loss: 160.6252 - val_mean_squared_error: 160.6252
#
# Epoch 00113: val_mean_squared_error did not improve from 135.15456
# Epoch 114/200
# 27/27 - 0s - loss: 137.7932 - mean_squared_error: 137.7932 - val_loss: 135.8204 - val_mean_squared_error: 135.8204
#
# Epoch 00114: val_mean_squared_error did not improve from 135.15456
# Epoch 115/200
# 27/27 - 0s - loss: 138.0561 - mean_squared_error: 138.0561 - val_loss: 174.9041 - val_mean_squared_error: 174.9041
#
# Epoch 00115: val_mean_squared_error did not improve from 135.15456
# Epoch 116/200
# 27/27 - 0s - loss: 150.4854 - mean_squared_error: 150.4854 - val_loss: 148.4440 - val_mean_squared_error: 148.4440
#
# Epoch 00116: val_mean_squared_error did not improve from 135.15456
# Epoch 117/200
# 27/27 - 0s - loss: 147.5113 - mean_squared_error: 147.5113 - val_loss: 136.3112 - val_mean_squared_error: 136.3112
#
# Epoch 00117: val_mean_squared_error did not improve from 135.15456
# Epoch 118/200
# 27/27 - 0s - loss: 155.7076 - mean_squared_error: 155.7076 - val_loss: 137.4933 - val_mean_squared_error: 137.4933
#
# Epoch 00118: val_mean_squared_error did not improve from 135.15456
# Epoch 119/200
# 27/27 - 0s - loss: 137.9983 - mean_squared_error: 137.9983 - val_loss: 140.5439 - val_mean_squared_error: 140.5439
# Epoch 00119: val_mean_squared_error did not improve from 135.15456
# Epoch 120/200
# 27/27 - 0s - loss: 135.2140 - mean_squared_error: 135.2140 - val_loss: 135.8287 - val_mean_squared_error: 135.8287
#
# Epoch 00120: val_mean_squared_error did not improve from 135.15456
# Epoch 121/200
# 27/27 - 0s - loss: 135.3823 - mean_squared_error: 135.3823 - val_loss: 138.7891 - val_mean_squared_error: 138.7891
#
# Epoch 00121: val_mean_squared_error did not improve from 135.15456
# Epoch 122/200
# 27/27 - 0s - loss: 131.6017 - mean_squared_error: 131.6017 - val_loss: 134.8172 - val_mean_squared_error: 134.8172
#
# Epoch 00122: val_mean_squared_error improved from 135.15456 to 134.81725, saving model to best_model_2.h5
# Epoch 123/200
# 27/27 - 0s - loss: 138.0844 - mean_squared_error: 138.0844 - val_loss: 141.6556 - val_mean_squared_error: 141.6556
#
# Epoch 00123: val_mean_squared_error did not improve from 134.81725
# Epoch 124/200
# 27/27 - 0s - loss: 132.7389 - mean_squared_error: 132.7389 - val_loss: 159.6977 - val_mean_squared_error: 159.6977
#
# Epoch 00124: val_mean_squared_error did not improve from 134.81725
# Epoch 125/200
# 27/27 - 0s - loss: 138.6224 - mean_squared_error: 138.6224 - val_loss: 146.0132 - val_mean_squared_error: 146.0132
#
# Epoch 00125: val_mean_squared_error did not improve from 134.81725
# Epoch 126/200
# 27/27 - 0s - loss: 143.5381 - mean_squared_error: 143.5381 - val_loss: 152.9845 - val_mean_squared_error: 152.9845
#
# Epoch 00126: val_mean_squared_error did not improve from 134.81725
# Epoch 127/200
# 27/27 - 0s - loss: 138.2782 - mean_squared_error: 138.2782 - val_loss: 136.6241 - val_mean_squared_error: 136.6241
#
# Epoch 00127: val_mean_squared_error did not improve from 134.81725
# Epoch 128/200
# 27/27 - 0s - loss: 134.5982 - mean_squared_error: 134.5982 - val_loss: 148.9635 - val_mean_squared_error: 148.9635
#
# Epoch 00128: val_mean_squared_error did not improve from 134.81725
# Epoch 129/200
# 27/27 - 0s - loss: 132.6382 - mean_squared_error: 132.6382 - val_loss: 134.2103 - val_mean_squared_error: 134.2103
#
# Epoch 00129: val_mean_squared_error improved from 134.81725 to 134.21030, saving model to best_model_2.h5
# Epoch 130/200
# 27/27 - 0s - loss: 133.1873 - mean_squared_error: 133.1873 - val_loss: 136.5090 - val_mean_squared_error: 136.5090
#
# Epoch 00130: val_mean_squared_error did not improve from 134.21030
# Epoch 131/200
# 27/27 - 0s - loss: 134.8291 - mean_squared_error: 134.8291 - val_loss: 133.8665 - val_mean_squared_error: 133.8665
#
# Epoch 00131: val_mean_squared_error improved from 134.21030 to 133.86647, saving model to best_model_2.h5
# Epoch 132/200
# 27/27 - 0s - loss: 140.8606 - mean_squared_error: 140.8606 - val_loss: 156.0441 - val_mean_squared_error: 156.0441
#
# Epoch 00132: val_mean_squared_error did not improve from 133.86647
# Epoch 133/200
# 27/27 - 0s - loss: 135.3833 - mean_squared_error: 135.3833 - val_loss: 148.3229 - val_mean_squared_error: 148.3229
#
# Epoch 00133: val_mean_squared_error did not improve from 133.86647
# Epoch 134/200
# 27/27 - 0s - loss: 134.9724 - mean_squared_error: 134.9724 - val_loss: 134.8254 - val_mean_squared_error: 134.8255
#
# Epoch 00134: val_mean_squared_error did not improve from 133.86647
# Epoch 135/200
# 27/27 - 0s - loss: 131.7161 - mean_squared_error: 131.7161 - val_loss: 138.7821 - val_mean_squared_error: 138.7821
#
# Epoch 00135: val_mean_squared_error did not improve from 133.86647
# Epoch 136/200
# 27/27 - 0s - loss: 134.0057 - mean_squared_error: 134.0057 - val_loss: 133.8660 - val_mean_squared_error: 133.8660
#
# Epoch 00136: val_mean_squared_error improved from 133.86647 to 133.86597, saving model to best_model_2.h5
# Epoch 137/200
# 27/27 - 0s - loss: 134.4559 - mean_squared_error: 134.4559 - val_loss: 148.6654 - val_mean_squared_error: 148.6654
#
# Epoch 00137: val_mean_squared_error did not improve from 133.86597
# Epoch 138/200
# 27/27 - 0s - loss: 137.6598 - mean_squared_error: 137.6598 - val_loss: 149.9058 - val_mean_squared_error: 149.9058
#
# Epoch 00138: val_mean_squared_error did not improve from 133.86597
# Epoch 139/200
# 27/27 - 0s - loss: 136.8622 - mean_squared_error: 136.8622 - val_loss: 135.1237 - val_mean_squared_error: 135.1237
#
# Epoch 00139: val_mean_squared_error did not improve from 133.86597
# Epoch 140/200
# 27/27 - 0s - loss: 133.4935 - mean_squared_error: 133.4935 - val_loss: 134.0537 - val_mean_squared_error: 134.0537
#
# Epoch 00140: val_mean_squared_error did not improve from 133.86597
# Epoch 141/200
# 27/27 - 0s - loss: 129.8011 - mean_squared_error: 129.8011 - val_loss: 133.4469 - val_mean_squared_error: 133.4469
#
# Epoch 00141: val_mean_squared_error improved from 133.86597 to 133.44687, saving model to best_model_2.h5
# Epoch 142/200
# 27/27 - 0s - loss: 131.5388 - mean_squared_error: 131.5388 - val_loss: 144.2316 - val_mean_squared_error: 144.2316
#
# Epoch 00142: val_mean_squared_error did not improve from 133.44687
# Epoch 143/200
# 27/27 - 0s - loss: 131.7906 - mean_squared_error: 131.7906 - val_loss: 135.4524 - val_mean_squared_error: 135.4524
#
# Epoch 00143: val_mean_squared_error did not improve from 133.44687
# Epoch 144/200
# 27/27 - 0s - loss: 134.2968 - mean_squared_error: 134.2968 - val_loss: 137.2169 - val_mean_squared_error: 137.2169
#
# Epoch 00144: val_mean_squared_error did not improve from 133.44687
# Epoch 145/200
# 27/27 - 0s - loss: 131.8466 - mean_squared_error: 131.8466 - val_loss: 139.1349 - val_mean_squared_error: 139.1349
#
# Epoch 00145: val_mean_squared_error did not improve from 133.44687
# Epoch 146/200
# 27/27 - 0s - loss: 134.3609 - mean_squared_error: 134.3609 - val_loss: 133.8503 - val_mean_squared_error: 133.8503
#
# Epoch 00146: val_mean_squared_error did not improve from 133.44687
# Epoch 147/200
# 27/27 - 0s - loss: 131.1538 - mean_squared_error: 131.1538 - val_loss: 132.8614 - val_mean_squared_error: 132.8614
#
# Epoch 00147: val_mean_squared_error improved from 133.44687 to 132.86142, saving model to best_model_2.h5
# Epoch 148/200
# 27/27 - 0s - loss: 134.4789 - mean_squared_error: 134.4789 - val_loss: 139.5850 - val_mean_squared_error: 139.5850
#
# Epoch 00148: val_mean_squared_error did not improve from 132.86142
# Epoch 149/200
# 27/27 - 0s - loss: 130.9238 - mean_squared_error: 130.9238 - val_loss: 135.6725 - val_mean_squared_error: 135.6725
#
# Epoch 00149: val_mean_squared_error did not improve from 132.86142
# Epoch 150/200
# 27/27 - 0s - loss: 136.0773 - mean_squared_error: 136.0773 - val_loss: 137.0953 - val_mean_squared_error: 137.0953
#
# Epoch 00150: val_mean_squared_error did not improve from 132.86142
# Epoch 151/200
# 27/27 - 0s - loss: 132.6403 - mean_squared_error: 132.6403 - val_loss: 135.4832 - val_mean_squared_error: 135.4832
#
# Epoch 00151: val_mean_squared_error did not improve from 132.86142
# Epoch 152/200
# 27/27 - 0s - loss: 130.4871 - mean_squared_error: 130.4871 - val_loss: 132.4084 - val_mean_squared_error: 132.4084
#
# Epoch 00152: val_mean_squared_error improved from 132.86142 to 132.40837, saving model to best_model_2.h5
# Epoch 153/200
# 27/27 - 0s - loss: 134.0293 - mean_squared_error: 134.0293 - val_loss: 132.6874 - val_mean_squared_error: 132.6874
#
# Epoch 00153: val_mean_squared_error did not improve from 132.40837
# Epoch 154/200
# 27/27 - 0s - loss: 132.4881 - mean_squared_error: 132.4881 - val_loss: 133.2484 - val_mean_squared_error: 133.2484
#
# Epoch 00154: val_mean_squared_error did not improve from 132.40837
# Epoch 155/200
# 27/27 - 0s - loss: 128.7782 - mean_squared_error: 128.7782 - val_loss: 132.2498 - val_mean_squared_error: 132.2498
#
# Epoch 00155: val_mean_squared_error improved from 132.40837 to 132.24983, saving model to best_model_2.h5
# Epoch 156/200
# 27/27 - 0s - loss: 129.4316 - mean_squared_error: 129.4316 - val_loss: 132.0433 - val_mean_squared_error: 132.0433
#
# Epoch 00156: val_mean_squared_error improved from 132.24983 to 132.04330, saving model to best_model_2.h5
# Epoch 157/200
# 27/27 - 0s - loss: 132.3442 - mean_squared_error: 132.3442 - val_loss: 135.3687 - val_mean_squared_error: 135.3687
#
# Epoch 00157: val_mean_squared_error did not improve from 132.04330
# Epoch 158/200
# 27/27 - 0s - loss: 135.9623 - mean_squared_error: 135.9623 - val_loss: 158.7445 - val_mean_squared_error: 158.7445
#
# Epoch 00158: val_mean_squared_error did not improve from 132.04330
# Epoch 159/200
# 27/27 - 0s - loss: 133.8324 - mean_squared_error: 133.8324 - val_loss: 142.6288 - val_mean_squared_error: 142.6288
# Epoch 00159: val_mean_squared_error did not improve from 132.04330
# Epoch 160/200
# 27/27 - 0s - loss: 134.8741 - mean_squared_error: 134.8741 - val_loss: 152.2406 - val_mean_squared_error: 152.2406
#
# Epoch 00160: val_mean_squared_error did not improve from 132.04330
# Epoch 161/200
# 27/27 - 0s - loss: 131.3708 - mean_squared_error: 131.3708 - val_loss: 142.1859 - val_mean_squared_error: 142.1860
#
# Epoch 00161: val_mean_squared_error did not improve from 132.04330
# Epoch 162/200
# 27/27 - 0s - loss: 133.4634 - mean_squared_error: 133.4634 - val_loss: 153.1081 - val_mean_squared_error: 153.1081
#
# Epoch 00162: val_mean_squared_error did not improve from 132.04330
# Epoch 163/200
# 27/27 - 0s - loss: 140.4866 - mean_squared_error: 140.4866 - val_loss: 160.3735 - val_mean_squared_error: 160.3735
#
# Epoch 00163: val_mean_squared_error did not improve from 132.04330
# Epoch 164/200
# 27/27 - 0s - loss: 137.8170 - mean_squared_error: 137.8170 - val_loss: 139.9393 - val_mean_squared_error: 139.9393
#
# Epoch 00164: val_mean_squared_error did not improve from 132.04330
# Epoch 165/200
# 27/27 - 0s - loss: 134.6999 - mean_squared_error: 134.6999 - val_loss: 136.2435 - val_mean_squared_error: 136.2435
#
# Epoch 00165: val_mean_squared_error did not improve from 132.04330
# Epoch 166/200
# 27/27 - 0s - loss: 131.2446 - mean_squared_error: 131.2446 - val_loss: 136.3545 - val_mean_squared_error: 136.3545
#
# Epoch 00166: val_mean_squared_error did not improve from 132.04330
# Epoch 167/200
# 27/27 - 0s - loss: 135.0699 - mean_squared_error: 135.0699 - val_loss: 138.1748 - val_mean_squared_error: 138.1748
#
# Epoch 00167: val_mean_squared_error did not improve from 132.04330
# Epoch 168/200
# 27/27 - 0s - loss: 131.4412 - mean_squared_error: 131.4412 - val_loss: 133.3659 - val_mean_squared_error: 133.3659
#
# Epoch 00168: val_mean_squared_error did not improve from 132.04330
# Epoch 169/200
# 27/27 - 0s - loss: 130.0635 - mean_squared_error: 130.0635 - val_loss: 133.8135 - val_mean_squared_error: 133.8135
#
# Epoch 00169: val_mean_squared_error did not improve from 132.04330
# Epoch 170/200
# 27/27 - 0s - loss: 128.4053 - mean_squared_error: 128.4053 - val_loss: 138.9877 - val_mean_squared_error: 138.9877
#
# Epoch 00170: val_mean_squared_error did not improve from 132.04330
# Epoch 171/200
# 27/27 - 0s - loss: 134.2493 - mean_squared_error: 134.2493 - val_loss: 135.1443 - val_mean_squared_error: 135.1443
#
# Epoch 00171: val_mean_squared_error did not improve from 132.04330
# Epoch 172/200
# 27/27 - 0s - loss: 128.9918 - mean_squared_error: 128.9918 - val_loss: 137.7867 - val_mean_squared_error: 137.7867
#
# Epoch 00172: val_mean_squared_error did not improve from 132.04330
# Epoch 173/200
# 27/27 - 0s - loss: 133.1382 - mean_squared_error: 133.1382 - val_loss: 132.3588 - val_mean_squared_error: 132.3588
#
# Epoch 00173: val_mean_squared_error did not improve from 132.04330
# Epoch 174/200
# 27/27 - 0s - loss: 132.8978 - mean_squared_error: 132.8978 - val_loss: 133.0547 - val_mean_squared_error: 133.0547
#
# Epoch 00174: val_mean_squared_error did not improve from 132.04330
# Epoch 175/200
# 27/27 - 0s - loss: 133.1140 - mean_squared_error: 133.1140 - val_loss: 135.8289 - val_mean_squared_error: 135.8289
#
# Epoch 00175: val_mean_squared_error did not improve from 132.04330
# Epoch 176/200
# 27/27 - 0s - loss: 130.8059 - mean_squared_error: 130.8059 - val_loss: 133.6666 - val_mean_squared_error: 133.6666
#
# Epoch 00176: val_mean_squared_error did not improve from 132.04330
# Epoch 00176: early stopping

# %%
saved_model = load_model('best_model_2.h5')

# %%
train_preds = saved_model.predict(x_train)
test_preds = saved_model.predict(x_test)
print('Training RMSE for neural networks baseline model: {}'.format(mean_squared_error(y_train, train_preds)**0.5))
print('Testing RMSE for neural networks baseline model: {}'.format(mean_squared_error(y_test, test_preds)**0.5))
# Out:
# Training RMSE for neural networks baseline model: 11.30028410203231
# Testing RMSE for neural networks baseline model: 11.491009421698765

# %%
def beat_vegas(result, vegas, prediction):
    tie = 0
    games = 0
    wins = 0
    win_total = 0
    loss = 0
    loss_total = 0
    
    for i in range(len(result)):
        if ((result[i]>vegas[i]) & (prediction[i]>vegas[i])):
            wins += 1
            games += 1
            win_total += abs(vegas[i]-prediction[i])
            
        elif ((result[i]<vegas[i]) & (prediction[i]<vegas[i])):
            wins += 1
            games += 1
            win_total += abs(vegas[i]-prediction[i])
            
        elif (result[i]==vegas[i]):
            tie += 1
            
        else:
            loss += 1
            games += 1
            loss_total += abs(vegas[i]-prediction[i])
            
    win_rate = (wins/games)*100
    win_distance = win_total/wins
    loss_distance = loss_total/loss
    
    print('Beat Vegas {}% of the time'.format(win_rate))
    print('Vegas RMSE: {}'.format(mean_squared_error(result, vegas)**0.5))
    print('Our RMSE: {}'.format(mean_squared_error(result, prediction)**0.5))
    print('When we beat Vegas, our prediction is {} points away from the Vegas spread.'.format(win_distance))
    print('When we lose to Vegas, our prediction is {} points away from the Vegas spread.'.format(loss_distance))

# %%
beat_vegas(y_test, x_test['Home Win By (Vegas)'], test_preds)
# Out:
# Beat Vegas 63.41647770219198% of the time
# Vegas RMSE: 12.41746477088067
# Our RMSE: 11.491009421698765
# When we beat Vegas, our prediction is [3.0192564] points away from the Vegas spread.
# When we lose to Vegas, our prediction is [1.9418343] points away from the Vegas spread.
